# %%
# %run classification.py "binary"
# Out:
# Using settings: {'clip': True, 'use_regularization': True, 'epochs': 20, 'C': 0.03, 'use_embeddings': True, 'attention_hops': 20}
# Using model settings {'vocab_size': 20000, 'lstm_hidden_dimension': 50, 'timesteps': 200, 'd_a': 100, 'batch_size': 1024}
# Running EPOCH 1
# avg_loss is tensor(0.7827, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.6657, device='cuda:0')
# Running EPOCH 2
# avg_loss is tensor(0.6867, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.7756, device='cuda:0')
# Running EPOCH 3
# avg_loss is tensor(0.6217, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8206, device='cuda:0')
# Running EPOCH 4
# avg_loss is tensor(0.5686, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8517, device='cuda:0')
# Running EPOCH 5
# avg_loss is tensor(0.5242, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8777, device='cuda:0')
# Running EPOCH 6
# ...
