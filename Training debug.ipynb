# %%
# %run classification.py "binary"
# Out:
# Using TensorFlow backend.
# Using settings: {'use_regularization': True, 'use_embeddings': True, 'epochs': 20, 'attention_hops': 20, 'clip': True, 'C': 0.03}
# Using model settings {'batch_size': 1024, 'vocab_size': 20000, 'timesteps': 200, 'd_a': 100, 'lstm_hidden_dimension': 50}
# Running EPOCH 1
# avg_loss is tensor(0.7673, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.6762, device='cuda:0')
# Running EPOCH 2
# avg_loss is tensor(0.6529, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8044, device='cuda:0')
# Running EPOCH 3
# avg_loss is tensor(0.6022, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8336, device='cuda:0')
# Running EPOCH 4
# avg_loss is tensor(0.5406, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8708, device='cuda:0')
# Running EPOCH 5
# avg_loss is tensor(0.4873, device='cuda:0', dtype=torch.float64)
# Accuracy of the model tensor(0.8967, device='cuda:0')
# ...
