# %%
import xml.etree.cElementTree as ElementTree

# %%
e = xml.etree.ElementTree.parse('coliee/entailment/EE.xml').getroot()

# %%
entries = e.findall('entry')

# %%
entries
# Out:
# [<Element 'entry' at 0x104fd1d68>,
#  <Element 'entry' at 0x104fe1bd8>,
#  <Element 'entry' at 0x104fed728>,
#  <Element 'entry' at 0x104ff6458>,
#  <Element 'entry' at 0x104ffacc8>,
#  <Element 'entry' at 0x104fffe58>,
#  <Element 'entry' at 0x105006e08>,
#  <Element 'entry' at 0x10501fbd8>,
#  <Element 'entry' at 0x1050249a8>,
#  <Element 'entry' at 0x105027db8>,
#  <Element 'entry' at 0x10502a7c8>,
#  <Element 'entry' at 0x10502f458>,
#  <Element 'entry' at 0x1050327c8>,
#  <Element 'entry' at 0x10503c278>,
#  <Element 'entry' at 0x105040188>,
#  <Element 'entry' at 0x1050408b8>,
#  <Element 'entry' at 0x1050430e8>,
#  <Element 'entry' at 0x105047458>,
#  <Element 'entry' at 0x105047d68>,
#  <Element 'entry' at 0x10504be58>,
#  <Element 'entry' at 0x10505cb88>,
#  <Element 'entry' at 0x10506bbd8>,
#  <Element 'entry' at 0x1050749a8>,
#  <Element 'entry' at 0x10507cf98>,
#  <Element 'entry' at 0x105080d68>,
#  <Element 'entry' at 0x10508c6d8>,
#  <Element 'entry' at 0x105090048>,
# ...
